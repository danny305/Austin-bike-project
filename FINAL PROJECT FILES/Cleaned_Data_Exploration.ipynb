# %%
import sklearn as sk
import pandas as pd
import numpy as np
from os import getenv
from datetime import datetime
from amb_sdk.sdk import DarwinSdk
import matplotlib.pyplot as plt

# %matplotlib inline

pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Import Raw Data Files
# The B-Cycle-Trips is not the original Raw data file.
# The original one was too big to upload to github so this one is a truncated version.
# The processing steps taken to truncate it to fit on github will be shown, however.

# %%
cycle_df = pd.read_csv('./data/Original_Austin_B-Cycle_Trips.csv')
weather_df = pd.read_csv('./data/austin_weather.csv')

# %%
cycle_df.head()
# Out:
#       Trip ID                     Membership Type  Bicycle ID Checkout Date  \
# 0  9900285854        Annual (San Antonio B-cycle)       207.0    10/26/2014
# 1  9900285855      24-Hour Kiosk (Austin B-cycle)       969.0    10/26/2014
# 2  9900285856  Annual Membership (Austin B-cycle)       214.0    10/26/2014
# 3  9900285857      24-Hour Kiosk (Austin B-cycle)       745.0    10/26/2014
# 4  9900285858      24-Hour Kiosk (Austin B-cycle)       164.0    10/26/2014
#
#   Checkout Time  Checkout Kiosk ID  \
# 0      13:12:00             2537.0
# 1      13:12:00             2498.0
# 2      13:12:00             2537.0
# 3      13:12:00                NaN
# 4      13:12:00             2538.0
#
#                                       Checkout Kiosk  Return Kiosk ID  \
# 0                                     West & 6th St.           2707.0
# 1            Convention Center / 4th St. @ MetroRail           2566.0
# 2                                     West & 6th St.           2496.0
# 3  Zilker Park at Barton Springs & William Barton...              NaN
# 4                    Bullock Museum @ Congress & MLK              NaN
#
#                                         Return Kiosk  Trip Duration Minutes  \
# 0                               Rainey St @ Cummings                     76
# 1                      Pfluger Bridge @ W 2nd Street                     58
# 2                                     8th & Congress                      8
# 3  Zilker Park at Barton Springs & William Barton...                     28
# 4                   Convention Center/ 3rd & Trinity                     15
#
#    Month    Year
# 0   10.0  2014.0
# 1   10.0  2014.0
# 2   10.0  2014.0
# 3   10.0  2014.0
# 4   10.0  2014.0

# %%
cycle_df.describe()
# Out:
#             Trip ID    Bicycle ID  Checkout Kiosk ID  Return Kiosk ID  \
# count  1.077929e+06  1.077206e+06       1.054775e+06     1.053516e+06
# mean   3.250189e+09  6.399591e+02       2.845409e+03     2.843819e+03
# std    4.638169e+09  8.042368e+02       5.571200e+02     5.565237e+02
# min    8.269930e+06  3.000000e+00       1.001000e+03     1.001000e+03
# 25%    1.505886e+07  2.260000e+02       2.504000e+03     2.503000e+03
# 50%    1.719355e+07  4.590000e+02       2.565000e+03     2.565000e+03
# 75%    9.900083e+09  8.620000e+02       3.377000e+03     3.377000e+03
# max    9.900353e+09  1.426400e+04       4.062000e+03     4.062000e+03
#
#        Trip Duration Minutes          Month           Year
# count           1.077929e+06  618479.000000  618479.000000
# mean            2.721814e+01       5.887185    2015.340026
# std             8.700783e+01       3.206358       1.019771
# min             0.000000e+00       1.000000    2013.000000
# 25%             6.000000e+00       3.000000    2014.000000
# 50%             1.200000e+01       5.000000    2015.000000
# 75%             2.600000e+01       9.000000    2016.000000
# max             2.129600e+04      12.000000    2017.000000

# %%
weather_df.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
#   SeaLevelPressureAvgInches SeaLevelPressureLowInches VisibilityHighMiles  \
# 0                     29.68                     29.59                  10
# 1                     30.13                     29.87                  10
# 2                     30.49                     30.41                  10
# 3                     30.45                      30.3                  10
# 4                     30.33                     30.27                  10
#
#   VisibilityAvgMiles VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  7                  2          20          4          31
# 1                 10                  5          16          6          25
# 2                 10                 10           8          3          12
# 3                 10                  7          12          4          20
# 4                 10                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T
#
# [5 rows x 21 columns]

# %%
weather_df.describe()
# Out:
#          TempHighF     TempAvgF     TempLowF
# count  1319.000000  1319.000000  1319.000000
# mean     80.862775    70.642911    59.902957
# std      14.766523    14.045904    14.190648
# min      32.000000    29.000000    19.000000
# 25%      72.000000    62.000000    49.000000
# 50%      83.000000    73.000000    63.000000
# 75%      92.000000    83.000000    73.000000
# max     107.000000    93.000000    81.000000

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Type of conversion

# %%
print('\nBefore:')
print(cycle_df[['Checkout Date', 'Checkout Time']].dtypes)

cycle_df['Checkout Date'] = pd.to_datetime(
    cycle_df['Checkout Date'], infer_datetime_format=True
    ).dt.normalize() 

cycle_df['Checkout Time'] = pd.to_timedelta(
    cycle_df['Checkout Time']) 

print('\nAfter:')
print(cycle_df[['Checkout Date', 'Checkout Time']].dtypes)
# Out:
# Before:
# Checkout Date    object
# Checkout Time    object
# dtype: object
#
# After:
# Checkout Date     datetime64[ns]
# Checkout Time    timedelta64[ns]
# dtype: object

# %%
print('\nBefore:')
print(weather_df['Date'].dtypes)

weather_df['Date'] = pd.to_datetime(
    weather_df['Date'], infer_datetime_format=True
    ).dt.normalize() 

print('\nAfter:')
print(weather_df['Date'].dtypes)
# Out:
# Before:
# object
#
# After:
# datetime64[ns]

# %% [markdown]
# ### Fill in missing values for the Month and Year columns

# %%
cycle_df['Month'] = cycle_df.apply(lambda x: x['Checkout Date'].month, axis=1)

cycle_df['Year']  = cycle_df.apply(lambda x: x['Checkout Date'].year, axis=1)

# %% [markdown]
# ### Make sure all cycle dates overlap with weather dates
#
# The dates we are going to use are 12/21/13 to 7/31/17.

# %%
print('Before:')

print('Cycle Trips Earliest Data',cycle_df['Checkout Date'].dt.date.min())
print('Cycle Trips Latest Data',cycle_df['Checkout Date'].dt.date.max())

print('Weather Earliest Data',weather_df['Date'].dt.date.min())
print('Weather Latest Data',weather_df['Date'].dt.date.max())


cycle_df = cycle_df[
    cycle_df['Checkout Date'].between('2013-12-21', 
                                            '2017-07-31', 
                                            inclusive=True)
]


print('After:')

print('Cycle Trips Earliest Data',cycle_df['Checkout Date'].dt.date.min())
print('Cycle Trips Latest Data',cycle_df['Checkout Date'].dt.date.max())

print('Weather Earliest Data',weather_df['Date'].dt.date.min())
print('Weather Latest Data',weather_df['Date'].dt.date.max())
# Out:
# Before:
# Cycle Trips Earliest Data 2013-12-21
# Cycle Trips Latest Data 2018-10-31
# Weather Earliest Data 2013-12-21
# Weather Latest Data 2017-07-31
# After:
# Cycle Trips Earliest Data 2013-12-21
# Cycle Trips Latest Data 2017-07-31
# Weather Earliest Data 2013-12-21
# Weather Latest Data 2017-07-31

# %% [markdown]
# # Exploration

# %% [markdown]
# ## Comparing Checkout Kiosk and Kiosk ID columns

# %%
no_kiosk_id_df = cycle_df[cycle_df[['Checkout Kiosk ID','Return Kiosk ID']].isnull().any(axis=1)]


print(len(no_kiosk_id_df))
no_kiosk_id_df.head(100)
# Out:
# 34131
#         Trip ID                     Membership Type  Bicycle ID Checkout Date  \
# 3    9900285857      24-Hour Kiosk (Austin B-cycle)       745.0    2014-10-26
# 4    9900285858      24-Hour Kiosk (Austin B-cycle)       164.0    2014-10-26
# 5    9900285859      24-Hour Kiosk (Austin B-cycle)        37.0    2014-10-26
# 9    9900285863      24-Hour Kiosk (Austin B-cycle)       385.0    2014-10-26
# 11   9900285865      24-Hour Kiosk (Austin B-cycle)        52.0    2014-10-26
# 18   9900285872      24-Hour Kiosk (Austin B-cycle)       484.0    2014-10-26
# 25   9900285879      24-Hour Kiosk (Austin B-cycle)       114.0    2014-10-26
# 32   9900285886      24-Hour Kiosk (Austin B-cycle)       920.0    2014-10-26
# 33   9900285887      24-Hour Kiosk (Austin B-cycle)       539.0    2014-10-26
# 34   9900285888      24-Hour Kiosk (Austin B-cycle)       164.0    2014-10-26
# 40   9900285894      24-Hour Kiosk (Austin B-cycle)       661.0    2014-10-26
# 56   9900285910      24-Hour Kiosk (Austin B-cycle)       745.0    2014-10-26
# 57   9900285911      24-Hour Kiosk (Austin B-cycle)        16.0    2014-10-26
# 66   9900285920  Annual Membership (Austin B-cycle)       407.0    2014-10-26
# 75   9900285929      24-Hour Kiosk (Austin B-cycle)       882.0    2014-10-26
# 80   9900285934      24-Hour Kiosk (Austin B-cycle)       284.0    2014-10-26
# 81   9900285935      24-Hour Kiosk (Austin B-cycle)       970.0    2014-10-26
# 94   9900285948      24-Hour Kiosk (Austin B-cycle)        27.0    2014-10-26
# 95   9900285949      24-Hour Kiosk (Austin B-cycle)       214.0    2014-10-26
# 111  9900285965      24-Hour Kiosk (Austin B-cycle)       219.0    2014-10-26
# 113  9900285967      24-Hour Kiosk (Austin B-cycle)       856.0    2014-10-26
# 114  9900285968      24-Hour Kiosk (Austin B-cycle)       759.0    2014-10-26
# 132  9900285986      24-Hour Kiosk (Austin B-cycle)       947.0    2014-10-26
# 151  9900286005      24-Hour Kiosk (Austin B-cycle)       206.0    2014-10-26
# 170  9900286024      24-Hour Kiosk (Austin B-cycle)        27.0    2014-10-26
# 172  9900286026      24-Hour Kiosk (Austin B-cycle)        20.0    2014-10-26
# 180  9900286034      24-Hour Kiosk (Austin B-cycle)       470.0    2014-10-26
# 182  9900286035      24-Hour Kiosk (Austin B-cycle)       214.0    2014-10-26
# 183  9900286036      24-Hour Kiosk (Austin B-cycle)       669.0    2014-10-26
# 197  9900286049      24-Hour Kiosk (Austin B-cycle)       479.0    2014-10-26
# 232  9900286084   7-Day Membership (Austin B-cycle)       185.0    2014-10-26
# 237  9900286089      24-Hour Kiosk (Austin B-cycle)       158.0    2014-10-26
# 261  9900286113      24-Hour Kiosk (Austin B-cycle)       920.0    2014-10-26
# 266  9900286118  Annual Membership (Austin B-cycle)       406.0    2014-10-26
# 301  9900286151      24-Hour Kiosk (Austin B-cycle)       247.0    2014-10-26
# 304  9900286154  Annual Membership (Austin B-cycle)       406.0    2014-10-26
# 309  9900286159      24-Hour Kiosk (Austin B-cycle)       445.0    2014-10-26
# 548  9900286397      24-Hour Kiosk (Austin B-cycle)       550.0    2014-10-27
# 549  9900286398      24-Hour Kiosk (Austin B-cycle)       861.0    2014-10-27
# 567  9900286416      24-Hour Kiosk (Austin B-cycle)        28.0    2014-10-27
# 573  9900286422      24-Hour Kiosk (Austin B-cycle)       160.0    2014-10-27
# 574  9900286423      24-Hour Kiosk (Austin B-cycle)       158.0    2014-10-27
# 577  9900286426      24-Hour Kiosk (Austin B-cycle)       976.0    2014-10-27
# 578  9900286427      24-Hour Kiosk (Austin B-cycle)       575.0    2014-10-27
# 579  9900286428      24-Hour Kiosk (Austin B-cycle)       141.0    2014-10-27
# 580  9900286429      24-Hour Kiosk (Austin B-cycle)       867.0    2014-10-27
# 588  9900286437      24-Hour Kiosk (Austin B-cycle)       327.0    2014-10-27
# 590  9900286439      24-Hour Kiosk (Austin B-cycle)        49.0    2014-10-27
# 591  9900286440      24-Hour Kiosk (Austin B-cycle)       160.0    2014-10-27
# 592  9900286441      24-Hour Kiosk (Austin B-cycle)       158.0    2014-10-27
# 593  9900286442      24-Hour Kiosk (Austin B-cycle)       285.0    2014-10-27
# 598  9900286447  Annual Membership (Austin B-cycle)       483.0    2014-10-27
# 606  9900286455      24-Hour Kiosk (Austin B-cycle)        64.0    2014-10-27
# 607  9900286456      24-Hour Kiosk (Austin B-cycle)        36.0    2014-10-27
# 615  9900286464   7-Day Membership (Austin B-cycle)       412.0    2014-10-27
# 617  9900286466   7-Day Membership (Austin B-cycle)       621.0    2014-10-27
# 621  9900286470      24-Hour Kiosk (Austin B-cycle)        29.0    2014-10-27
# 622  9900286471      24-Hour Kiosk (Austin B-cycle)       209.0    2014-10-27
# 623  9900286472      24-Hour Kiosk (Austin B-cycle)       440.0    2014-10-27
# 624  9900286473      24-Hour Kiosk (Austin B-cycle)       540.0    2014-10-27
# 628  9900286477   7-Day Membership (Austin B-cycle)       588.0    2014-10-27
#
#     Checkout Time  Checkout Kiosk ID  \
# 3        13:12:00                NaN
# 4        13:12:00             2538.0
# 5        13:12:00                NaN
# 9        13:12:00                NaN
# 11       13:12:00             2566.0
# 18       13:12:00                NaN
# 25       13:12:00                NaN
# 32       14:12:00                NaN
# 33       14:12:00                NaN
# 34       14:12:00                NaN
# 40       14:12:00                NaN
# 56       14:12:00                NaN
# 57       14:12:00                NaN
# 66       14:12:00             2707.0
# 75       14:12:00             2711.0
# 80       14:12:00             2545.0
# 81       14:12:00             2545.0
# 94       15:12:00             2550.0
# 95       15:12:00             2496.0
# 111      15:12:00                NaN
# 113      15:12:00                NaN
# 114      15:12:00                NaN
# 132      15:12:00                NaN
# 151      15:12:00             2502.0
# 170      16:12:00                NaN
# 172      16:12:00                NaN
# 180      16:12:00                NaN
# 182      16:12:00                NaN
# 183      16:12:00                NaN
# 197      16:12:00                NaN
# 232      17:12:00             2549.0
# 237      17:12:00             2496.0
# 261      17:12:00                NaN
# 266      17:12:00             2575.0
# 301      18:12:00                NaN
# 304      18:12:00                NaN
# 309      18:12:00             2549.0
# 313      18:12:00                NaN
# 317      18:12:00                NaN
# 333      19:12:00             2501.0
# 344      19:12:00             2495.0
# 345      19:12:00             2495.0
# 356      20:12:00                NaN
# 378      21:12:00                NaN
# 405      07:12:00             2503.0
# 407      07:12:00             2502.0
# 411      07:12:00             2566.0
# 430      08:12:00                NaN
# 431      08:12:00             2503.0
# 432      08:12:00                NaN
# 447      09:12:00             2544.0
# 469      10:12:00             2502.0
# 470      10:12:00                NaN
# 471      10:12:00                NaN
# 480      10:12:00             2707.0
# 481      10:12:00             2494.0
# 482      10:12:00             2494.0
# 485      10:12:00             2566.0
# 486      10:12:00             2566.0
# 488      10:12:00                NaN
# 489      10:12:00             2712.0
# 490      10:12:00             2566.0
# 492      10:12:00                NaN
# 493      10:12:00                NaN
# 495      10:12:00             2563.0
# 496      10:12:00             2563.0
# 505      11:12:00                NaN
# 507      11:12:00                NaN
# 508      11:12:00                NaN
# 510      11:12:00                NaN
# 515      11:12:00             2572.0
# 519      11:12:00             2499.0
# 520      11:12:00             2499.0
# 532      11:12:00                NaN
# 543      12:12:00             2536.0
# 545      12:12:00             2536.0
# 548      12:12:00                NaN
# 549      12:12:00                NaN
# 567      12:12:00             2572.0
# 573      12:12:00             2561.0
# 574      12:12:00             2561.0
# 577      12:12:00                NaN
# 578      12:12:00                NaN
# 579      12:12:00                NaN
# 580      12:12:00                NaN
# 588      12:12:00             2504.0
# 590      12:12:00             2504.0
# 591      12:12:00                NaN
# 592      12:12:00                NaN
# 593      13:12:00             2575.0
# 598      13:12:00             2561.0
# 606      13:12:00             2712.0
# 607      13:12:00             2712.0
# 615      13:12:00                NaN
# 617      13:12:00                NaN
# 621      13:12:00             2538.0
# 622      13:12:00             2566.0
# 623      13:12:00             2566.0
# 624      13:12:00             2538.0
# 628      14:12:00                NaN
#
#                                         Checkout Kiosk  Return Kiosk ID  \
# 3    Zilker Park at Barton Springs & William Barton...              NaN
# 4                      Bullock Museum @ Congress & MLK              NaN
# 5    Zilker Park at Barton Springs & William Barton...           2545.0
# 9    Zilker Park at Barton Springs & William Barton...           2545.0
# 11                       Pfluger Bridge @ W 2nd Street              NaN
# 18                    Convention Center/ 3rd & Trinity           2549.0
# 25                   East 11th Street at Victory Grill           2547.0
# 32                    Convention Center/ 3rd & Trinity              NaN
# 33                    Convention Center/ 3rd & Trinity              NaN
# 34                    Convention Center/ 3rd & Trinity              NaN
# 40                    Convention Center/ 3rd & Trinity           2575.0
# 56   Zilker Park at Barton Springs & William Barton...           2569.0
# 57   Zilker Park at Barton Springs & William Barton...           2569.0
# 66                                Rainey St @ Cummings              NaN
# 75                         Barton Springs @ Kinney Ave              NaN
# 80                             ACC - Rio Grande & 12th              NaN
# 81                             ACC - Rio Grande & 12th              NaN
# 94               Republic Square @ Guadalupe & 4th St.              NaN
# 95                                      8th & Congress              NaN
# 111                   Convention Center/ 3rd & Trinity              NaN
# 113                            Red River @ LBJ Library           2537.0
# 114                            Red River @ LBJ Library           2537.0
# 132                   Convention Center/ 3rd & Trinity           2566.0
# 151                         Barton Springs & Riverside              NaN
# 170  Zilker Park at Barton Springs & William Barton...           2549.0
# 485     10  2014
# 486     10  2014
# 488     10  2014
# 489     10  2014
# 490     10  2014
# 492     10  2014
# 493     10  2014
# 495     10  2014
# 496     10  2014
# 505     10  2014
# 507     10  2014
# 508     10  2014
# 510     10  2014
# 515     10  2014
# 519     10  2014
# 520     10  2014
# 532     10  2014
# 543     10  2014
# 545     10  2014
# 548     10  2014
# 549     10  2014
# 567     10  2014
# 573     10  2014
# 574     10  2014
# 577     10  2014
# 578     10  2014
# 579     10  2014
# 580     10  2014
# 588     10  2014
# 590     10  2014
# 591     10  2014
# 592     10  2014
# 593     10  2014
# 598     10  2014
# 606     10  2014
# 607     10  2014
# 615     10  2014
# 617     10  2014
# 621     10  2014
# 622     10  2014
# 623     10  2014
# 624     10  2014
# 628     10  2014

# %% [markdown]
# #### Notes
# Produced about 34000 rows that had atleast one of the 2 columns has a  null value.
# Rows that have a missing checkout kiosk ID or a missing return kiosk ID correlate with their corresponding Checkout Kiosk or Return Kiosk.
# Thus, no information is lost if the Kiosk ID columns are dropped because all the information is present in the checkout Kiosk  or Return Kiosk columns.

# %%
cycle_df = cycle_df.drop(['Checkout Kiosk ID','Return Kiosk ID'], axis=1)
cycle_df.head()
# Out:
#       Trip ID                     Membership Type  Bicycle ID Checkout Date  \
# 0  9900285854        Annual (San Antonio B-cycle)       207.0    2014-10-26
# 1  9900285855      24-Hour Kiosk (Austin B-cycle)       969.0    2014-10-26
# 2  9900285856  Annual Membership (Austin B-cycle)       214.0    2014-10-26
# 3  9900285857      24-Hour Kiosk (Austin B-cycle)       745.0    2014-10-26
# 4  9900285858      24-Hour Kiosk (Austin B-cycle)       164.0    2014-10-26
#
#   Checkout Time                                     Checkout Kiosk  \
# 0      13:12:00                                     West & 6th St.
# 1      13:12:00            Convention Center / 4th St. @ MetroRail
# 2      13:12:00                                     West & 6th St.
# 3      13:12:00  Zilker Park at Barton Springs & William Barton...
# 4      13:12:00                    Bullock Museum @ Congress & MLK
#
#                                         Return Kiosk  Trip Duration Minutes  \
# 0                               Rainey St @ Cummings                     76
# 1                      Pfluger Bridge @ W 2nd Street                     58
# 2                                     8th & Congress                      8
# 3  Zilker Park at Barton Springs & William Barton...                     28
# 4                   Convention Center/ 3rd & Trinity                     15
#
#    Month  Year
# 0     10  2014
# 1     10  2014
# 2     10  2014
# 3     10  2014
# 4     10  2014

# %% [markdown]
# ### Trip Duration Minutes distribution

# %%
cycle_df['Trip Duration Minutes'].value_counts().sort_index().head(100).plot()

# %% [markdown]
# ### Create Cycle DF Variants
# The data was filtered based on Trip Durations:
#    * remove rides shorter than 2 minutes
#    * include rides only shorter than 2 minutes
#    * remove rides shorter than 75 minutes
#    * include rides only longer than 75 minutes

# %%
cycle_df_no_0_2 = cycle_df.drop(cycle_df[
    cycle_df['Trip Duration Minutes'].isin([0,1,2])].index)

cycle_df_only_0_2 = cycle_df.drop(cycle_df[
    cycle_df['Trip Duration Minutes'] > 2].index)

cycle_df_less_75_min =  cycle_df.drop(cycle_df[
    cycle_df['Trip Duration Minutes'] > 75].index)

cycle_df_longer_75_min =  cycle_df.drop(cycle_df[
    cycle_df['Trip Duration Minutes'] < 75].index)



all_cycle_df = [cycle_df,
                cycle_df_no_0_2,
                cycle_df_only_0_2, 
                cycle_df_less_75_min, cycle_df_longer_75_min,
               ]


for df in all_cycle_df:
    print(df.shape)
# Out:
# (649231, 10)
# (620432, 10)
# (28799, 10)
# (604383, 10)
# (45758, 10)

# %% [markdown]
# ## View Cycle DF variants Trip Duration in Minutes

# %%
all_cycle_df[1]['Trip Duration Minutes'].value_counts().sort_index().head(100).plot()

# %%
all_cycle_df[2]['Trip Duration Minutes'].value_counts().sort_index().head(100).plot()

# %%
all_cycle_df[3]['Trip Duration Minutes'].value_counts().sort_index().head(100).plot()

# %%
all_cycle_df[4]['Trip Duration Minutes'].value_counts().sort_index().head(100).plot()

# %% [markdown]
# ## View Trip Duration by day of the week

# %%
for df in all_cycle_df:
    df['Checkout WeekDay'] = df['Checkout Date'].dt.day_name()

# %%
df = all_cycle_df[0]
cycle_weekdays = df.groupby('Checkout WeekDay')
for name,group in cycle_weekdays:
    group['Trip Duration Minutes'].value_counts().sort_index()\
    .head(50).plot(legend=True,label=name)

# %%
df = all_cycle_df[1]
cycle_weekdays = df.groupby('Checkout WeekDay')
for name,group in cycle_weekdays:
    group['Trip Duration Minutes'].value_counts().sort_index()\
    .head(50).plot(legend=True,label=name)

# %%
df = all_cycle_df[2]
cycle_weekdays = df.groupby('Checkout WeekDay')
for name,group in cycle_weekdays:
    group['Trip Duration Minutes'].value_counts().sort_index()\
    .head(50).plot(legend=True,label=name)

# %%
df = all_cycle_df[3]
cycle_weekdays = df.groupby('Checkout WeekDay')
for name,group in cycle_weekdays:
    group['Trip Duration Minutes'].value_counts().sort_index()\
    .head(50).plot(legend=True,label=name)

# %%
df = all_cycle_df[4]
cycle_weekdays = df.groupby('Checkout WeekDay')
for name,group in cycle_weekdays:
    group['Trip Duration Minutes'].value_counts().sort_index()\
    .head(50).plot(legend=True,label=name)

# %% [markdown]
# ## Notes
# Trips are twice as long on Saturday and Sunday then all other days. (~11-12 min compared to ~6-7)
# The distribution of Friday Saturday and Sunday is right shifted compared to the 4 days.
# Monday-Thursday distributions are nearly identical.

# %% [markdown]
# ## View Time Duration by Month

# %%
df = all_cycle_df[0]
cycle_months = df.groupby('Month')
for index,(name,group) in enumerate(cycle_months):
#     if 4 < index < 9 :
#         continue
#     elif index >12:
#         continue 
    group['Trip Duration Minutes'].value_counts().sort_index()\
    .head(40).plot(legend=True,label=name)

# %%
df = all_cycle_df[1]
cycle_months = df.groupby('Month')
for index,(name,group) in enumerate(cycle_months):
#     if 4 < index < 9 :
#         continue
#     elif index >12:
#         continue 
    group['Trip Duration Minutes'].value_counts().sort_index()\
    .head(40).plot(legend=True,label=name)

# %%
df = all_cycle_df[2]
cycle_months = df.groupby('Month')
for index,(name,group) in enumerate(cycle_months):
#     if 4 < index < 9 :
#         continue
#     elif index >12:
#         continue 
    group['Trip Duration Minutes'].value_counts().sort_index()\
    .head(40).plot(legend=True,label=name)

# %%
df = all_cycle_df[3]
cycle_months = df.groupby('Month')
for index,(name,group) in enumerate(cycle_months):
#     if 4 < index < 9 :
#         continue
#     elif index >12:
#         continue 
    group['Trip Duration Minutes'].value_counts().sort_index()\
    .head(40).plot(legend=True,label=name)

# %%
df = all_cycle_df[4]
cycle_months = df.groupby('Month')
for index,(name,group) in enumerate(cycle_months):
#     if 4 < index < 9 :
#         continue
#     elif index >12:
#         continue 
    group['Trip Duration Minutes'].value_counts().sort_index()\
    .head(40).plot(legend=True,label=name)

# %% [markdown]
# ## Notes
# March is the most popular month.
# October and May are tied for second but October trips length are a bit longer.
# December is the least popular month by far.
# June through September are practically identical.
# January, February, and April are about the same, with February being the lowest.
# February is about tied with November.
#
# Overall there are 4 tiers:
# 1. March
# 2. May and October
# 3. All months besides December
# 4. December

# %% [markdown]
# ## View Checkout Time by Day of the Week

# %%
df = all_cycle_df[0]
cycle_weekdays = df.groupby('Checkout WeekDay')
for index,(name,group) in enumerate(cycle_weekdays):
#     if index not in [1,6]:
#         continue
    group['Checkout Time'].value_counts().sort_index()\
    .plot(legend=True,label=name)

# %%
df = all_cycle_df[1]
cycle_weekdays = df.groupby('Checkout WeekDay')
for index,(name,group) in enumerate(cycle_weekdays):
#     if index not in [1,6]:
#         continue
    group['Checkout Time'].value_counts().sort_index()\
    .plot(legend=True,label=name)

# %%
df = all_cycle_df[2]
cycle_weekdays = df.groupby('Checkout WeekDay')
for index,(name,group) in enumerate(cycle_weekdays):
#     if index not in [1,6]:
#         continue
    group['Checkout Time'].value_counts().sort_index()\
    .plot(legend=True,label=name)

# %%
df = all_cycle_df[3]
cycle_weekdays = df.groupby('Checkout WeekDay')
for index,(name,group) in enumerate(cycle_weekdays):
#     if index not in [1,6]:
#         continue
    group['Checkout Time'].value_counts().sort_index()\
    .plot(legend=True,label=name)

# %%
df = all_cycle_df[4]
cycle_weekdays = df.groupby('Checkout WeekDay')
for index,(name,group) in enumerate(cycle_weekdays):
#     if index not in [1,6]:
#         continue
    group['Checkout Time'].value_counts().sort_index()\
    .plot(legend=True,label=name)

# %% [markdown]
# ## Notes
# Majority trips between midnight and 3 am are on saturday and sunday.
# Thursday, Tuesday, Monday are about the same. Thursday is slightly taller in the afternoon.
# Tuesday and Wednesday are practically identical.
# Monday is slightly taller than Wednesday during peak hours.

# %% [markdown]
# ## Explore Checkout/Return Kiosks

# %%
df = all_cycle_df[1]

checkout_return_pairs = df.\
    groupby(['Checkout Kiosk','Return Kiosk']).size().reset_index()\
    .rename(columns={0:'counts'}) 

checkout_return_pairs = checkout_return_pairs\
    .sort_values('counts', ascending=False).reset_index()

# total_trips = checkout_return_pairs['counts'].sum()

# checkout_return_pairs['freq_%'] = checkout_return_pairs['counts']\
#     .map(lambda x: round(x/total_trips*100,4))


print("Shape of kiosk pair df: ",checkout_return_pairs.shape)


checkout_return_pairs.head(100)
# Out:
# Shape of kiosk pair df:  (5098, 4)
#     index                                     Checkout Kiosk  \
# 0    3949                               Riverside @ S. Lamar
# 1    3574                               Rainey St @ Cummings
# 2     196                                     2nd & Congress
# 3    1572                           City Hall / Lavaca & 2nd
# 4    4987                                        Zilker Park
# 5    5097  Zilker Park at Barton Springs & William Barton...
# 6    3355                      Pfluger Bridge @ W 2nd Street
# 7    1489                  Capitol Station / Congress & 11th
# 8    3225                                  Palmer Auditorium
# 9     993                         Barton Springs & Riverside
# 10   1153                                Barton Springs Pool
# 11    439                                        5th & Bowie
# 12   2735                Long Center @ South 1st & Riverside
# 13   2942           MoPac Pedestrian Bridge @ Veterans Drive
# 14    357                                     4th & Congress
# 15   1903                             Davis at Rainey Street
# 16    457                                        5th & Bowie
# 69            Convention Center / 4th St. @ MetroRail    1005
# 70                               Riverside @ S. Lamar    1005
# 71                               Riverside @ S. Lamar     995
# 72                           City Hall / Lavaca & 2nd     993
# 73                           City Hall / Lavaca & 2nd     986
# 74                           City Hall / Lavaca & 2nd     982
# 75                        Barton Springs @ Kinney Ave     975
# 76                        Barton Springs @ Kinney Ave     973
# 77                                     Plaza Saltillo     969
# 78                               Riverside @ S. Lamar     968
# 79                             Davis at Rainey Street     965
# 80                           City Hall / Lavaca & 2nd     948
# 81                               Riverside @ S. Lamar     940
# 82                               Rainey St @ Cummings     940
# 83                                   Guadalupe & 21st     937
# 84                           San Jacinto & 8th Street     927
# 85            Convention Center / 4th St. @ MetroRail     925
# 86                                     West & 6th St.     915
# 87                                     4th & Congress     913
# 88                Long Center @ South 1st & Riverside     907
# 89                                     8th & Congress     902
# 90                             Red River & 8th Street     902
# 91                                     2nd & Congress     900
# 92                                     4th & Congress     899
# 93                  Capitol Station / Congress & 11th     894
# 94                               Trinity & 6th Street     887
# 95                             Davis at Rainey Street     865
# 96                                        5th & Bowie     855
# 97                      Pfluger Bridge @ W 2nd Street     852
# 98                                     4th & Congress     850
# 99                           South Congress & Academy     845

# %% [markdown]
# ### Calculate Average and Mode for each Kiosk Pair

# %%
df = all_cycle_df[1]

groups = df.\
    groupby(['Checkout Kiosk','Return Kiosk'])


columns = ['Checkout Kiosk','Return Kiosk', 'Avg Trip Duration', 
          'Mode Trip Duration']
checkout_return_pairs_avg = pd.DataFrame(columns=columns)
for (checkout, checkin),group in groups:
    checkout_return_pairs_avg = checkout_return_pairs_avg\
        .append({col_name: value for col_name, value in 
                 zip(columns,[checkout,checkin,
                group['Trip Duration Minutes'].mean(),
                group['Trip Duration Minutes'].mode().max()])
                }, ignore_index=True)

checkout_return_pair_data = pd.merge(checkout_return_pairs, 
                                     checkout_return_pairs_avg,
                                     how='inner',
                                    left_on=['Checkout Kiosk',
                                             'Return Kiosk'],
                                    right_on=['Checkout Kiosk',
                                             'Return Kiosk'],
                                    )
checkout_return_pair_data.drop(columns='index', inplace=True)
#checkout_return_pair_data['Avg Trip Duration'].head(100).plot()
checkout_return_pair_data.head()
# Out:
#              Checkout Kiosk              Return Kiosk  counts  \
# 0      Riverside @ S. Lamar      Riverside @ S. Lamar    7799
# 1      Rainey St @ Cummings      Rainey St @ Cummings    4997
# 2            2nd & Congress            2nd & Congress    3681
# 3  City Hall / Lavaca & 2nd  City Hall / Lavaca & 2nd    3422
# 4               Zilker Park               Zilker Park    3226
#
#    Avg Trip Duration Mode Trip Duration
# 0          52.916015                 27
# 1          63.470082                 25
# 2          75.861451                 29
# 3          74.004383                  3
# 4          59.846559                 44

# %% [markdown]
# ### Trend between kiosk pairs based on Time Duration of trip

# %% [markdown]
# ### Kiosk pairs where the average trip was less than 15 minutes

# %%
checkout_return_pair_data[checkout_return_pair_data[
    'Avg Trip Duration'
] < 15].head(40)
# Out:
#                               Checkout Kiosk  \
# 11                               5th & Bowie
# 14                            4th & Congress
# 16                               5th & Bowie
# 18                                3rd & West
# 20   Convention Center / 4th St. @ MetroRail
# 174  Convention Center / 4th St. @ MetroRail     646          14.654799
#
#     Mode Trip Duration
# 11                   6
# 14                   6
# 16                   5
# 18                   4
# 20                   5
# 23                   5
# 24                   4
# 26                   8
# 27                   5
# 35                   7
# 44                   4
# 47                   4
# 48                   4
# 62                   5
# 63                   6
# 66                   7
# 69                   8
# 72                   5
# 77                   8
# 85                   8
# 87                   7
# 91                   6
# 92                   6
# 103                  7
# 114                  7
# 119                  6
# 122                 10
# 123                  4
# 126                  6
# 129                  5
# 130                  7
# 136                  5
# 137                  7
# 148                  8
# 153                  6
# 164                  8
# 166                  4
# 172                  6
# 173                  5
# 174                  8

# %% [markdown]
# ### Kiosk pairs where the average trip was longer than 25 minutes

# %%
checkout_return_pair_data[checkout_return_pair_data[
    'Avg Trip Duration'
] > 25].head(40)
# Out:
#                                        Checkout Kiosk  \
# 0                                Riverside @ S. Lamar
# 1                                Rainey St @ Cummings
# 2                                      2nd & Congress
# 3                            City Hall / Lavaca & 2nd
# 4                                         Zilker Park
# 5   Zilker Park at Barton Springs & William Barton...
# 6                       Pfluger Bridge @ W 2nd Street
# 7                   Capitol Station / Congress & 11th
# 8                                   Palmer Auditorium
# 9                          Barton Springs & Riverside
# 10                                Barton Springs Pool
# 12                Long Center @ South 1st & Riverside
# 13           MoPac Pedestrian Bridge @ Veterans Drive
# 15                             Davis at Rainey Street
# 17            Convention Center / 4th St. @ MetroRail
# 19                        Barton Springs @ Kinney Ave
# 22                                     4th & Congress
# 28                                        5th & Bowie
# 31                  Convention Center / 3rd & Trinity
# 33                             South Congress & James
# 34                               Riverside @ S. Lamar
# 37                           UT West Mall @ Guadalupe
# 40                               Riverside @ S. Lamar
# 45                               Rainey St @ Cummings
# 49                                     8th & Congress
# 50                    Bullock Museum @ Congress & MLK
# 53  State Capitol Visitors Garage @ San Jacinto & ...
# 55                               Riverside @ S. Lamar
# 56                         South Congress & Elizabeth
# 58                           South Congress & Academy
# 68                  Capitol Station / Congress & 11th
# 70                      Pfluger Bridge @ W 2nd Street
# 73                  Capitol Station / Congress & 11th
# 78           MoPac Pedestrian Bridge @ Veterans Drive
# 81                Long Center @ South 1st & Riverside
# 83                                   Guadalupe & 21st
# 84                           San Jacinto & 8th Street
# 86                                     West & 6th St.
# 88                               Riverside @ S. Lamar
# 94                               Trinity & 6th Street
#
#                                          Return Kiosk  counts  \
# 0                                Riverside @ S. Lamar    7799
# 1                                Rainey St @ Cummings    4997
# 2                                      2nd & Congress    3681
# 3                            City Hall / Lavaca & 2nd    3422
# 4                                         Zilker Park    3226
# 5   Zilker Park at Barton Springs & William Barton...    3125
# 6                       Pfluger Bridge @ W 2nd Street    3077
# 7                   Capitol Station / Congress & 11th    2929
# 8                                   Palmer Auditorium    2571
# 9                          Barton Springs & Riverside    2527
# 10                                Barton Springs Pool    2473
# 12                Long Center @ South 1st & Riverside    2344
# 13           MoPac Pedestrian Bridge @ Veterans Drive    2263
# 15                             Davis at Rainey Street    2135
# 17            Convention Center / 4th St. @ MetroRail    2005
# 19                        Barton Springs @ Kinney Ave    1833
# 22                                     4th & Congress    1746
# 28                                        5th & Bowie    1491
# 31                  Convention Center / 3rd & Trinity    1459
# 33                             South Congress & James    1362
# 34                               Rainey St @ Cummings    1336
# 37                           UT West Mall @ Guadalupe    1258
# 40                                        Zilker Park    1226
# 45                               Riverside @ S. Lamar    1186
# 49                                     8th & Congress    1134
# 50                    Bullock Museum @ Congress & MLK    1131
# 53  State Capitol Visitors Garage @ San Jacinto & ...    1109
# 55                      Pfluger Bridge @ W 2nd Street    1105
# 56                         South Congress & Elizabeth    1105
# 58                           South Congress & Academy    1102
# 68                                     2nd & Congress    1012
# 70                               Riverside @ S. Lamar    1005
# 73                           City Hall / Lavaca & 2nd     986
# 78                               Riverside @ S. Lamar     968
# 81                               Riverside @ S. Lamar     940
# 83                                   Guadalupe & 21st     937
# 84                           San Jacinto & 8th Street     927
# 86                                     West & 6th St.     915
# 88                Long Center @ South 1st & Riverside     907
# 94                               Trinity & 6th Street     887
#
#     Avg Trip Duration Mode Trip Duration
# 0           52.916015                 27
# 1           63.470082                 25
# 2           75.861451                 29
# 3           74.004383                  3
# 4           59.846559                 44
# 5           53.919360                 24
# 6           57.786155                 27
# 7           54.652783                 29
# 8           64.497083                 11
# 9           77.552434                 58
# 10          55.419733                 24
# 12          68.203925                 27
# 13          67.685815                 44
# 15          70.025761                  3
# 17          74.422444                  3
# 19          66.306601                 29
# 22          68.903207                 29
# 28          67.488263                 12
# 31          72.143249                 28
# 33          73.534508                  3
# 34          31.315868                 19
# 37          76.551669                 28
# 40          27.120718                 11
# 45          36.440135                 19
# 49          76.244268                 29
# 50          55.325376                 29
# 53          61.296664                 30
# 55          30.729412                  3
# 56          71.504977                 24
# 58          71.688748                 58
# 68          34.098814                 10
# 70          37.576119                  3
# 73          27.388438                  8
# 78          31.513430                 20
# 81          26.336170                  4
# 83          69.358591                 29
# 84          85.593312                 63
# 86          51.350820                 13
# 88          27.902977                  5
# 94          70.909808                 29

# %% [markdown]
# ## Note
# Most of the long trip durations are returned to the station they were checked out of.
#
# All of the short trips are returned at a different station.

# %% [markdown]
# ## Remove nontrip Kiosk Pairs

# %%
rm_kiosk = ['Stolen','Missing',
              'Main Shop','Repair Shop', 'Shop',
              'Customer Service','Main Office',]
cleaned_checkout_return_pair_data = checkout_return_pair_data[
    ~checkout_return_pair_data['Return Kiosk'].isin(rm_kiosk) &
    ~checkout_return_pair_data['Checkout Kiosk'].isin(rm_kiosk)
]


# cleaned_checkout_return_pair_data[
#     cleaned_checkout_return_pair_data['counts'] > 100
# ]

bad_checkout_return_pair_data = checkout_return_pair_data[
    checkout_return_pair_data['Return Kiosk'].isin(rm_kiosk) |
    checkout_return_pair_data['Checkout Kiosk'].isin(rm_kiosk)
]

bad_checkout_return_pair_data.sort_values(
    'counts', ascending=False, inplace=True
)

print('Not Real Trips: ',bad_checkout_return_pair_data.counts.sum())

bad_checkout_return_pair_data.head(10)
# Out:
# Not Real Trips:  968
# /Users/Danny/.virtualenvs/CS_329E/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                          Checkout Kiosk  \
# 1683                         East 11th St. & San Marcos
# 1709                                        Main Office
# 2137  State Capitol Visitors Garage @ San Jacinto & ...
# 2456                                        Main Office
# 3261                                        5th & Bowie
# 3284                         East 11th St. & San Marcos
# 3394                                        Main Office
# 3493                                        Main Office
# 3496                                   17th & Guadalupe
# 3470            Convention Center / 4th St. @ MetroRail
#
#                                            Return Kiosk  counts  \
# 1683                                        Main Office      76
# 1709                         East 11th St. & San Marcos      74
# 2137                                        Main Office      49
# 2456  State Capitol Visitors Garage @ San Jacinto & ...      36
# 3261                                   Customer Service      16
# 3284                                        Repair Shop      16
# 3394                         Barton Springs & Riverside      14
# 3493                                        Main Office      13
# 3496                                        Main Office      13
# 3470                                   Customer Service      13
#
#       Avg Trip Duration Mode Trip Duration
# 1683          28.921053                 29
# 1709           7.702703                  6
# 2137          15.551020                  4
# 2456           6.777778                  3
# 3261         730.875000                 29
# 3284          84.125000                 12
# 3394          11.214286                 14
# 3493          63.000000                 29
# 3496          11.461538                  6
# 3470         156.692308                 29

# %% [markdown]
# ## Notes
# 968 trips are not real. 681 come from not having a real Return Kiosk.
# These are bikes that were checked out and were not checked back in for another customer to use.

# %% [markdown]
# ## Compare cycle dates to weather dates

# %%
print('weather dates:', len(weather_df['Date'].unique()))
print('cycle dates:  ', len(cycle_df['Checkout Date'].unique()))

missing_dates = pd.date_range(start = '2013-12-21', end = '2017-07-31' )\
    .difference(cycle_df['Checkout Date'])

print(len(missing_dates))
missing_dates
# Out:
# weather dates: 1319
# cycle dates:   1257
# 62
# DatetimeIndex(['2014-08-31', '2016-04-01', '2016-04-02', '2016-04-03',
#                '2016-04-04', '2016-04-05', '2016-04-06', '2016-04-07',
#                '2016-04-08', '2016-04-09', '2016-04-10', '2016-04-11',
#                '2016-04-12', '2016-04-13', '2016-04-14', '2016-04-15',
#                '2016-04-16', '2016-04-17', '2016-04-18', '2016-04-19',
#                '2016-04-20', '2016-04-21', '2016-04-22', '2016-04-23',
#                '2016-04-24', '2016-04-25', '2016-04-26', '2016-04-27',
#                '2016-04-28', '2016-04-29', '2016-04-30', '2016-12-01',
#                '2016-12-02', '2016-12-03', '2016-12-04', '2016-12-05',
#                '2016-12-06', '2016-12-07', '2016-12-08', '2016-12-09',
#                '2016-12-10', '2016-12-11', '2016-12-12', '2016-12-13',
#                '2016-12-14', '2016-12-15', '2016-12-16', '2016-12-17',
#                '2016-12-18', '2016-12-19', '2016-12-20', '2016-12-21',
#                '2016-12-22', '2016-12-23', '2016-12-24', '2016-12-25',
#                '2016-12-26', '2016-12-27', '2016-12-28', '2016-12-29',
#                '2016-12-30', '2016-12-31'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## Notes
# It seems that the entire month of April and Decemeber for 2016 we have no data.
# The one other date is August 31, 2014.
# These rows were dropped from the weather csv.

# %% [markdown]
# ## Cleaning Final DF

# %%
new_weather_df = weather_df[~weather_df['Date'].isin(missing_dates)]
len(new_weather_df['Date'].unique())
# Out:
# 1257

# %%
df = all_cycle_df[1]
print(df.shape)

cleaned_df = df[
    ~df['Checkout Kiosk'].isin(rm_kiosk) &
    ~df['Return Kiosk'].isin(rm_kiosk)
]

cleaned_df.shape
# Out:
# (620432, 11)
# (619464, 11)

# %% [markdown]
# ## Creating CSV for feature engineering

# %%
cleaned_df.to_csv('./data/cleaned_final_b_cycle_data.csv', 
                  index=False)

new_weather_df.to_csv('./data/cleaned_austin_weather.csv',
                     index=False)
